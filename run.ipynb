# %% [markdown]
# # Create Jpeg images

# %%
# !python source/prepare_data/jpeg.py \
    --clean_image_dir "./data/test/Cus" \
    --jpeg_image_dir "./data/jpeg"
# Out:
# Start create jpeg with quality 20
# Done
# Start create jpeg with quality 30
# Done
# Start create jpeg with quality 40
# Done
# Start create jpeg with quality 50
# Done
# Start create jpeg with quality 60
# Done
# Start create jpeg with quality 70
# Done
# Start create jpeg with quality 80
# Done
# Start create jpeg with quality 90
# Done

# %% [markdown]
# # Create dataset

# %%
# !python source/prepare_data/crop.py \
    --img_dir "./data/Forms" \
    --train_dir "./data/train"\
    --valid_dir "./data/valid"
# Out:
# Start
# Conpletely 50 images
# Conpletely 100 images
# Conpletely 150 images
# Conpletely 200 images
# Conpletely 250 images
# Conpletely 300 images
# Conpletely 350 images
# Total batch 128003

# %% [markdown]
# # Train DnCNN model

# %%
# !python source/networks/main.py \
    --epoch 50 \
    --batch_size 16 \
    --lr 0.0001 \
    --phase "train" \
    --model "dncnn" \
    --checkpoint_dir './source/networks/checkpoint/DNCNN' \
    --train_dir "./data/train" \
    --valid_dir "./data/valid" \
    --tmp_dir "./data/tmp" \
    --gpu "1"
# Out:
# 2019-06-28 13:46:29.321308: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-06-28 13:46:30.050637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1392] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.6705
# pciBusID: 0000:04:00.0
# totalMemory: 10.91GiB freeMemory: 10.75GiB
# 2019-06-28 13:46:30.050679: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2019-06-28 13:46:30.302368: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-28 13:46:30.302404: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2019-06-28 13:46:30.302414: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# ...

# %% [markdown]
# # Train BCD model

# %%
# !python source/networks/main.py \
    --epoch 50 \
    --batch_size 16 \
    --lr 0.0001 \
    --phase "train" \
    --model "cbd" \
    --checkpoint_dir './source/networks/checkpoint/CBD' \
    --train_dir "./data/train" \
    --valid_dir "./data/valid" \
    --tmp_dir "./data/tmp" \
    --gpu "1"
# Out:
# 2019-06-28 13:54:04.981013: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-06-28 13:54:05.760115: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1392] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.6705
# pciBusID: 0000:04:00.0
# totalMemory: 10.91GiB freeMemory: 10.75GiB
# 2019-06-28 13:54:05.760152: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2019-06-28 13:54:06.006992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-28 13:54:06.007034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2019-06-28 13:54:06.007041: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# ...

# %% [markdown]
# # Test DnCNN model (with jpeg image)

# %%
# !python source/networks/main.py \
    --phase "test" \
    --model "dncnn" \
    --checkpoint_dir './source/networks/checkpoint/DNCNN' \
    --test_dir "./data/jpeg/20" \
    --save_dir "./results/DNCNN/Cus/20" \
    --gpu "0"\
    --jpeg_flag "1"
# Out:
# 2019-06-28 13:54:16.327206: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-06-28 13:54:18.397669: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1392] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.6705
# pciBusID: 0000:03:00.0
# totalMemory: 10.91GiB freeMemory: 8.76GiB
# 2019-06-28 13:54:18.397702: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2019-06-28 13:54:18.621876: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-28 13:54:18.621913: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2019-06-28 13:54:18.621921: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# ...

# %% [markdown]
# # Test DnCNN model (without jpeg image)

# %%
# !python source/networks/main.py \
    --phase "test" \
    --model "dncnn" \
    --checkpoint_dir './source/networks/checkpoint/DNCNN' \
    --test_dir "./data/test/Cus" \
    --save_dir "./results/DNCNN/Cus" \
    --tmp_dir "./data/tmp" \
    --gpu "0"\
    --jpeg_flag "0"
# Out:
# 2019-06-28 13:54:35.986695: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-06-28 13:54:36.766904: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1392] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.6705
# pciBusID: 0000:03:00.0
# totalMemory: 10.91GiB freeMemory: 8.76GiB
# 2019-06-28 13:54:36.766940: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2019-06-28 13:54:37.000395: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-28 13:54:37.000432: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2019-06-28 13:54:37.000441: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# ...

# %% [markdown]
# # Test CBD model (with jpeg image)

# %%
# !python source/networks/main.py \
    --phase "test" \
    --model "cbd" \
    --checkpoint_dir './source/networks/checkpoint/CBD' \
    --test_dir "./data/jpeg/20" \
    --save_dir "./results/CBD/Cus/20" \
    --gpu "0"\
    --jpeg_flag "1"

# %% [markdown]
# # Test CBD model (without jpeg image)

# %%
# !python source/networks/main.py \
    --phase "test" \
    --model "cbd" \
    --checkpoint_dir './source/networks/checkpoint/CBD' \
    --test_dir "./data/test/Cus" \
    --save_dir "./results/CBD/Cus" \
    --tmp_dir "./data/tmp" \
    --gpu "0"\
    --jpeg_flag "0"
